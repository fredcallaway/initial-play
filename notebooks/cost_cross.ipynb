# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_context('notebook', font_scale=1.3)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('../results/cost_cross.csv')
df.head()
# Out:
#       α    λ  level  m_λ      loss
# 0  0.05  0.1    0.2  0.8  0.656373
# 1  0.06  0.1    0.2  0.8  0.649667
# 2  0.07  0.1    0.2  0.8  0.643639
# 3  0.08  0.1    0.2  0.8  0.638948
# 4  0.09  0.1    0.2  0.8  0.634472

# %%
x = np.array([0,1])
m
# Out:
# array([0.36787944, 0.40656966])

# %%
df[costs].min()
# Out:
# α        0.05
# λ        0.05
# level    0.05
# m_λ      0.50
# dtype: float64

# %%
costs = ['α', 'λ', 'level', 'm_λ',]
default = [0.1, 0.1, 0.2, 0.8]
fig, axes = plt.subplots(1, 4, figsize=(20,5))
for i in range(4):
    plt.sca(axes[i])
    df.groupby(costs[i]).loss.mean().plot(ax=axes[i])
    plt.axvline(default[i], c='r', ls=':')
    plt.xscale('log')
# df.groupby('α').loss.mean().plot()
